# %% [markdown]
# G4
# Gerar o código em r para gerar o gráfico que correlacione o ICM, em suas quatro categorias, com o volume de tráfego. Usando como base de dados o Trabalho/bases-de-dados/condicoes-de-pavimento/condicoes-de-pavimento.Rdata, Trabalho/bases-de-dados/contagem-de-trafego/contagem-de-trafego.RData e Trabalho/bases-de-dados/definicao-de-pavimento/df_snv.RData

# %% [markdown]
# G7
# Fazer um código em R que analise a regressão linear entre a variável independente VMDA e a variável dependente ICM para as rodovias do Brasil.

# %% [markdown]
# ## G3 Carregar mais meses de pavimento para ver serie temporal
#
# Ver a pasta Trabalho/bases-de-dados/condicoes-de-pavimento/mes-a-mes.
# Fiz a carga da maioria dos meses de 2021.
#
# O arquivo "Trabalho/bases-de-dados/condicoes-de-pavimento/mes-a-mes/carga-icm-mes-a-mes.ipynb" mostra a carga e no final dá um exemplo de série temporal.
